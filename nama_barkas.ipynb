# %% [markdown]
# ### Project goals:
# * query all data with AVAIL label
# * identify product name, price, and seller phonenumber

# %%
from sql_functions import query_all, text_preprocessing
import warnings
warnings.filterwarnings("ignore")

data = query_all(['shortcode','caption','label'])
avail = data[data['label']=="AVAIL"]

avail
# Out:
#                                     shortcode  \
# 0     CdkKXK9p7hOdKxgtry4sggDIJtX94oAjuaEvz00
# 2     CdkJlJmpzRLEaFIxrn3FMQprY5ulloR_lnpC_40
# 5     Cdj-Qtwp6hQe589X95b9akSYwQZKN4dIeH-ArQ0
# 6     Cdj99kDJ1EIscvToboJ2lR3cOVz6_PPgNhbhCY0
# 7     Cdj6_M0JF6eVSkOcLvfUeMZvwW20NUG0qORlGY0
# ...                                       ...
# 1539  CeFiIkcPf4asBIrv-2sQ1TeAe7AvmBI4hkcPSo0
# 1540  CeFhttXP66xSJQjtBgBjaaioAJFTjM-9WAme4I0
# 1541  CeFg_PovzeAgjQ2hPSIVhhp2xnjc0ZD34F5Owc0
# 1542  CeFgY6sva-HsgW5HkLq1svWZ3b9GAVWC5QxMXg0
# 1543  CeFgCV5v0MW_rsRNuYRSNxagiAd4JpqDzS9UAM0
#
#                                                 caption  label
# 0     Nama barang : sepatu size 37\nKondisi : new bl...  AVAIL
# 2     Nama barang : VANS SLIP ON BLACK CLASSIC 7 us ...  AVAIL
# 5     1. Nama barang : Bruklat hitam fit to L\nKondi...  AVAIL
# 6     Nama barang : Sepatu Heels Payless VE Janine\n...  AVAIL
# 7     Nama Barang : ip xr 64gb red\nKondisi : mulus ...  AVAIL
# ...                                                 ...    ...
# 1539  • Di Jual : Realme 3\n• Kondisi : Normal smua\...  AVAIL
# 1540  • Di Jual : Samsung A6 plus\n• Kondisi : norma...  AVAIL
# 1541  📌Dijual : Kamera SONY ZV-1 & SONY Earbud WF-C5...  AVAIL
# 1542  📌Dijual : HDD External SEAGATE\n📌Keterangan : ...  AVAIL
# 1543  📌Dijual : 2 Tiket Konser Pam A Day in Yogyakar...  AVAIL
#
# [943 rows x 3 columns]

# %%
caption = avail.iloc[1,1]
caption
# Out:
# 'Nama barang : VANS SLIP ON BLACK CLASSIC 7 us / 39 eur / 25 cm\nKondisi : Baru, belum pernah dipakai\nHarga : 485.000 nego\n\nKontak\nWA : 088233813908\nIG : @citradewiandafebrian\n\nLokasi : tlogoadi mlati sleman yogyakarta'

# %%
import re

def to_list(line):
    words = re.findall("[a-z]+",line)
    return words

def word_refiner(keyword):
    if any([x in keyword for x in ["nama","nama_barang","dijual","di_jual","jual"]]):
        return "nama_barang"
    elif any([x in keyword for x in ["alasan","keterangan","kondisi","ket","spesifikasi"]]):
        return "keterangan"
    elif any([x in keyword for x in ["ig","instagram"]]):
        return "ig"
    elif "harga" in keyword:
        if all([x in keyword for x in ["harga","beli"]]):
            return "harga_beli"
        else:
            return "harga_jual"
    elif any([x in keyword for x in ["lokasi","alamat"]]):
        return "lokasi"
    elif any([x in keyword for x in ["kontak","wa","whatsapp","minat_hub"]]):
        if "wa" in to_list(keyword):
            return "kontak"
        elif any([x in keyword for x in ["kontak","whatsapp","minat_hub"]]):
            return "kontak"
        else:
            return keyword
    else:
        return keyword

class Caption:
    
    def __init__(self,text):
        self.caption = text
        self.text = text.split("\n")
        
    def to_dict(self):
        instance = {}
        for line in self.text:
            key = line.split(":")[0]
            value = ":".join(line.split(":")[1:]).strip().upper()
            if key != "" and value != "":
                key = key.lower().strip().replace(" ","_")
                if key == "ig":
                    value = value.lower().lstrip("@")
                instance.update({key: value})
        return instance
    
    def to_list(self):
        return [d.strip() for d in self.text if d.strip() != ""]
    
    def refine_dict(self):
        instance = self.to_dict()
        new_instance = [{word_refiner(key): value} for key,value in instance.items()]
        return new_instance
    
    def __str__(self):
        return re.sub("\s+"," ",self.caption).strip()
    
if __name__ == "__main__":
    
    # caption = Caption(avail.iloc[6,1])
    # print(caption.to_dict())
    
    keys = []
    for i in avail.index:
        caption = Caption(avail.loc[i,'caption'])
        new_keys = [[*d.keys()][0] for d in caption.refine_dict()]
        keys.extend(new_keys)
    keys = list(dict.fromkeys(keys))
print(len(keys))
keys
# Out:
# 242
# ['nama_barang',
#  'keterangan',
#  'harga_jual',
#  'kontak',
#  'ig',
#  'lokasi',
#  'warna',
#  'size',
#  'tinggi_heels',
#  'minus',
#  'bahan_meja',
#  'bahan_kursi',
#  'untuk_tanggal',
#  'harga_beli',
#  'kelengkapan',
#  'note',
#  'size_l',
#  'shade',
#  'size_s_(p',
#  '-_detail_kain',
#  '-_audio',
#  'masa_pemakaian',
#  'bonus',
#  'kondiai',
#  'fasilitas',
#  'check-in',
#  'check-out',
#  '~_rangka_kaki',
#  '~_kain',
#  '~_bantalan_sandaran_tangan',
#  '~_dudukan',
#  '~_sandaran_tangan',
#  '~_lebar_arm_rest',
#  '~_tinggi_sandaran',
#  '~_tinggi_dudukan',
#  '~_tinggi_arm_rest',
#  '~_dimensi_dudukan_kursi',
#  '~_dimensi_bantal_recline_kecil',
#  '~_dimensi_posisi_normal',
#  '~_dimensi_posisi_recline',
#  'bh',
#  'kabupaten',
#  'provinsi',
#  'luas_tanah',
#  'lebar_depan',
#  'hadap',
#  'sertipikat',
#  'warna_body_sepeda',
#  'baterai',
#  'kecepatan',
#  'jarak_tempuh',
#  'dinamo',
#  'ban',
#  'ukuran_sepeda_(cm)',
#  'lainnya',
#  '1._monitor',
#  '2._pross',
#  '3._mobo',
#  '4._vga',
#  '5._ram',
#  '6._ssd',
#  '7._hd',
#  '10._psu',
#  '11._case',
#  'fitur',
#  '•minus',
#  'ukuran',
#  'no_telf',
#  '📌minus',
#  'buat_mahasiswi_yang_berminat_bisa_hubungi_nomor_ini,_ibu_wati',
#  'iso',
#  '3',
#  '-_sise',
#  'wassap',
#  '1._luna_shirt_(tenun)',
#  '2._easy_hug_wrapped_outer',
#  '3._celana_panjang_wanita_hatori',
#  '4._alice_top_warna_blush',
#  '5._nadine_top',
#  '6._rubi_kaos_rib_sage_green',
#  '7._puffy_shoulder_top',
#  'cod',
#  '-_bh',
#  'minat_hub',
#  '-_lebar_depan_/_barat',
#  '-_lebar_samping_/_utara',
#  'minusnya',
#  '-_kekurangan',
#  '•_material',
#  '•_dimension',
#  '•_expandable',
#  '•_volume',
#  'jl.kaliurang_km',
#  '•item',
#  '•spek',
#  '2._jl_monjali_no_13d_(samping_lesehan_aldan_monjali)_(gmaps',
#  'open_daily',
#  'pakaian_cewek_,_bb_kurleb_57kg._tb',
#  'ricecooker',
#  'tv',
#  'dispenser',
#  'satu_set_alat_makan',
#  '-_fullset',
#  'untuk',
#  '-__3_pumping_modes',
#  '-__ukuran_corong_silicone_24mm_(option',
#  '-__rechargeable_battery',
#  '•_bobot',
#  '*_technology',
#  '*_sim',
#  '*_type',
#  '*_size',
#  '*_os',
#  '*_chipset',
#  '*_internal',
#  '*_kamera_belakang',
#  '*_kamera_depan',
#  '*_nfc',
#  '*_battery_health',
#  '🔥_follow',
#  'nb',
#  '📍_mapple_seturan/jakal/gejayn/godean_(11',
#  'maps',
#  'ukuran_dress',
#  'merk',
#  'rasio_layar_21',
#  '📌produk',
#  '📌_merk',
#  '=>_deskripsi',
#  'procesor',
#  'memory',
#  'storage',
#  'sistem_operasi',
#  '•disewakan',
#  'price',
#  'processor',
#  'ram',
#  'hdd',
#  'vga',
#  '📌cod',
#  'meja_p',
#  '•dijua',
#  'camera',
#  'true_tone',
#  '3utools',
#  'face_id',
#  '>helm',
#  '>sepatu',
#  '>ip__4s',
#  '>rice_cooker',
#  'luas_bangunan',
#  'listrik',
#  'air',
#  '-_wifi_(802.11a/b/h/n/ac)',
#  '-_baterai',
#  '-_kelengkapan',
#  '-_minus',
#  'pembelian',
#  'garansi',
#  '-_total_cores',
#  '-_total_threads',
#  '-_max_turbo_frequency',
#  '-_performance-core_max_turbo_frequency',
#  '-_performance-core_base_frequency',
#  '-_cache',
#  '-_total_l2_cache',
#  '-_processor_base_power',
#  '-_maximum_turbo_power',
#  '-_max_memory_size_(dependent_on_memory_type)',
#  '-_processor_graphics',
#  '-kualitas',
#  '-kelengkapan',
#  'bentuk',
#  'kamar',
#  'pross',
#  'os',
#  'ssd',
#  'front_camera',
#  'untuk_tgl',
#  'type_kamar',
#  'front_rise',
#  'lpaha',
#  'kondis',
#  '-tinggi',
#  '-lebar',
#  '-tebal',
#  'panjang_kabel',
#  'berat',
#  'graphics',
#  'hardisk',
#  'audio',
#  'dimensi',
#  'wifi/bluetooth',
#  'ports',
#  'brand',
#  'ukuran_jadi_sofa',
#  'ukuran_jadi_bed',
#  'pilihan_warna',
#  'cp',
#  '-_size',
#  'ambil_semua',
#  'ayam_utuh',
#  'lokas',
#  'free',
#  'kode_pos',
#  'feel',
#  'tebal',
#  'garansi_busa',
#  'deskripsi',
#  'yuk_yang_mau_tau_bisa_hubungi_aku_di',
#  'seri',
#  'kapasitas',
#  'hari_tanggal',
#  'kategori',
#  '•size',
#  '1._tas_kiri',
#  '2._tas_kanan',
#  'narahubung',
#  'garansi_resmi',
#  'prosesor_&_vga',
#  'ram_&_storage',
#  'layar',
#  'info_survey_n_lain2',
#  'lok.',
#  'beli',
#  '📌kelengkapan',
#  '📌_minus',
#  '•_processor',
#  '•_memory',
#  '•_storage',
#  '•_graphic',
#  '•_operating_system',
#  'info',
#  'ori',
#  'nomer_seri',
#  'box',
#  'kuitansi',
#  '-pajak',
#  '-oli',
#  'spesifikasi',
#  '*gak_nego_bonus',
#  '•_minus']
